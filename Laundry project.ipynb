# %%
from tkinter import *
from tkinter import ttk
import tkinter as tk
from PIL import ImageTk
from PIL import Image

def add_File():
    Name_Info = name.get()
    Roll_Info = str(rollNo.get())
    Gender_Info = gender.get()
    Email_Info = email.get()
    Contact_Info = str(contact.get())
    Dob_Info = dob.get()
    Address_Info = address.get()
    Laundry_Info = laundry.get()
    
    print(Name_Info)
    print(Roll_Info)
    print(Gender_Info)
    print(Email_Info)
    print(Contact_Info)
    print(Dob_Info)
    print(Address_Info)
    print(Laundry_Info)
    
    file = open("laundryFile.txt", "w")
    
    file.write("Full Name is :")
    file.write("\n")
    file.write(Name_Info)
    file.write("Laundry Roll Number :")
    file.write("\n")
    file.write(str(Roll_Info))
    file.write("Email Address is :")
    file.write("\n")
    file.write(Email_Info)
    file.write("Contact is :")
    file.write("\n")
    file.write(Contact_Info)
    file.write("Date Of Birth :")
    file.write("\n")
    file.write(Dob_Info)
    file.write("Address_Info :")
    file.write("\n")
    file.write(Address_Info)
    file.write("Laundry_Info")
    file.write("\n")
    file.write(Laundry_Info)
               
    
    file.close()
    

    
def checkChanges(a,b,c):
    prices={"Shirt":700,"Bed Sheet":800,"Under Wears":1600}
    Laundry=laundryVar.get()
    print(qtnVar.get())
    print(Laundry)
    print(prices[Laundry])
    unitPrice["text"]=f"Unit Price: {prices[Laundry]}"
    totalPrice["text"]=f"Total Price: {prices[Laundry]*qtyVar.get()}"
    
def newLaund():
    new_window1=Toplevel()
    new_window1.geometry(f"{screen_width}x{screen_height}")
    new_window1.config(bg="blue")
    new_window1.title(" LAUNDRY POINT OF SALE")    
    newLab = Label(new_window1,text="LAUNDRY POINT OF SALE",bd=10,relief=GROOVE,fg="red",bg="#f2a343",font=("times new romans",30,"bold"),pady=5)
    newLab.pack()
    
    newframe1 = LabelFrame(new_window1,relief=GROOVE,bg="white",height=200,width=1348,pady=3,padx=5,bd=5)
    newframe1.pack()
    
    newframe2 = Frame(new_window1,relief=GROOVE,bg="yellow",height=200,width=1348, pady=5,padx=4,bd=5)
    newframe2.pack()
    
    
    options=["Trouser","Shirt","Bed sheets","Underwears"]
    laundryVar = StringVar()
    pureWind1 = Label(newframe2,text="Select Type",font=("times new roman",30,"bold"),pady=3,fg="blue",padx=5,bd=20,width=600,relief=GROOVE).pack()
    laundryVar.set(options[1])
    laundryVar.trace_add("write",checkChanges)
    OptionMenu(newframe2,laundryVar,*options).pack()
    
    

    newframe4 = Frame(new_window1,relief=GROOVE,bg="pink",height=160,width=600,padx=3, pady=4,bd=5)
    newframe4.pack()
    
    
    qtnVar = IntVar()
    pureWind2 = Label(newframe4,text="Quantity Of Laundry",font=("times new roman",30,"bold"),fg="blue",pady=3,padx=5,bd=20,width=600,relief=GROOVE).pack()
    qtnVar.trace_add("write",checkChanges)
    Spinbox(newframe4,from_=1,to=100,textvariable=qtnVar).pack()
    
    newframe3 = Frame(new_window1,relief=GROOVE,bg="red")
    newframe3.pack(side= BOTTOM)
    unitPrice=Label(newframe3,text="Unit Price:700",pady=3,padx=5,bd=5,font=font14,fg="blue")
    unitPrice.pack()

    priceVar = StringVar()
    totalPrice = Label(newframe3,text="Total Price:700",height=90,width=578,fg="blue",pady=3,padx=5,bd=5,font=("times new romans",20,"bold"))
    totalPrice.pack()
 
    
    




root = Tk()
screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()
root.geometry(f"{screen_width}x{screen_height}")
root.config(bg="pink")
        
font10 = "{courier New} 10 normal"
font11 = "{U.S 101} 30 bold"
font12 = "Al-Aramco 11 bold"
font13 = "{courier New} 15 bold"
font14 = "{segie Ul} 15 bold"
font15 = "Arial 13 bold"
font16 = "{Segoe ul} 13 bold"
        
    
        
Label1=tk.Label(root,text="Laundry Management System",width=507,bd=9,relief=GROOVE,background="#091833", font=font11,fg="#f2a343")
Label1.pack(pady=5)
        
#===========================================Variables==============================================================================

rollNo = IntVar()
name = StringVar()
gender = StringVar()
email = StringVar()
contact = IntVar()
dob = StringVar()
address = StringVar()
laundry = StringVar()




            
            
        
        
#===========================================Manage_Frame========================================================================
ManageFrame = Frame(root,bd=4,relief=RIDGE,bg="yellow")
ManageFrame.place(x=20,y=100,width=450,height=585)
        
m_title=Label(ManageFrame,text="Manage Laundry",bg="red",fg="white",font=("times new romans",40,"bold"))
m_title.grid(row=0,column=0,columnspan=2,pady=20)
        
lbl_roll=Label(ManageFrame,text="ROLL No :",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_roll.grid(row=1,column=0,pady=10,padx=20,sticky="W")
txt_Roll=Entry(ManageFrame,font=("times new roman",15,"bold"),bd=5,relief=GROOVE,)
txt_Roll.grid(column=1,row=1,pady=10,padx=20,sticky="W")
        
        
lbl_name=Label(ManageFrame,text="NAME :",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_name.grid(row=2,column=0,pady=10,padx=20,sticky="W")
txt_name=Entry(ManageFrame,font=("times new roman",15,"bold"),bd=5,relief=GROOVE,textvariable=name)
txt_name.grid(column=1,row=2,pady=10,padx=20,sticky="W")
        
lbl_Email=Label(ManageFrame,text="EMAIL :",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_Email.grid(row=3,column=0,pady=10,padx=20,sticky="W")
txt_Email=Entry(ManageFrame,font=("times new roman",15,"bold"),bd=5,relief=GROOVE,textvariable=email)
txt_Email.grid(column=1,row=3,pady=10,padx=20,sticky="W")
        
lbl_Gender=Label(ManageFrame,text="GENDER :", bg="white",fg="black", font=("times new romans",20,"bold"))
lbl_Gender.grid(row=4,column=0,pady=10,padx=20,sticky="W")
        
Combo_gender =ttk.Combobox(ManageFrame,font=("times new romans",13,"bold") ,state="readonly")
Combo_gender["values"]=("Male","Female", "Other")
Combo_gender.grid(row=4,column=1,padx=20,pady=10)
                      
lbl_Contact=Label(ManageFrame,text="CONTACT :",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_Contact.grid(row=5,column=0,pady=10,padx=20,sticky="W")
txt_Contact=Entry(ManageFrame,font=("times new roman",15,"bold"),bd=5,relief=GROOVE,textvariable=contact)
txt_Contact.grid(column=1,row=5,pady=10,padx=20,sticky="W")
        
lbl_Dob=Label(ManageFrame,text="D.O.B:",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_Dob.grid(row=6,column=0,pady=10,padx=20,sticky="W")
txt_Dob=Entry(ManageFrame,font=("times new roman",15,"bold"),bd=5,relief=GROOVE,textvariable=dob)
txt_Dob.grid(column=1,row=6,pady=10,padx=20,sticky="W")
                        
lbl_Address=Label(ManageFrame,text="ADDRESS :",bg="white",fg="black",font=("times new romans",20,"bold"))
lbl_Address.grid(row=7,column=0,pady=10,padx=20,sticky="W")
txt_Address=Entry(ManageFrame,font=("times new romans",13,"bold"),bd=5,relief=GROOVE,textvariable=address)
txt_Address.grid(column=1,row=7,pady=10,padx=20,sticky="W")
        
btn_frame = Frame(ManageFrame,bd=3,relief=RIDGE,bg="black")
btn_frame.place(x=15,y=525,width=420)
        
#=====================================button frame========================================================================

addbtn =Button(btn_frame,text="Add",width=10,command=add_File).grid(row=0,column=0,padx=10,pady=10)
updbtn =Button(btn_frame,text="update",width=10).grid(row=0,column=1,padx=10,pady=10)
delbtn =Button(btn_frame,text="Delete",width=10).grid(row=0,column=2,padx=10,pady=10)
clrbtn =Button(btn_frame,text="Clear",width=10).grid(row=0,column=3,padx=10,pady=10)
        
#=====================================Detailed frame========================================================================
        
Details_frame = Frame(root,bd=4,relief=RIDGE,bg="yellow",padx=10)
Details_frame.place(x=500, y=100,width=880,height=585)
        
lbl_search = Label(Details_frame,text="Search by" ,fg="red",bg="yellow",font=("times new romans",20,"bold"))
lbl_search.grid(row=0,column=0,pady=10,padx=10,sticky="W")
        
Combo_search = ttk.Combobox(Details_frame,font=("times new romans",13,"bold") ,state="readonly")
Combo_search["values"]=("Roll No", "Name","Contact")
Combo_search.grid(row=0,column=1,padx=20,pady=10)
txt_search = Entry(Details_frame,font=("times new romans",13,"bold"),width=20,bd=5,relief=GROOVE)
txt_search.grid(row=0,column=1,pady=10,padx=20,sticky="W")
        
searchbtn = Button(Details_frame,text="Search", width=10,pady=5).grid(row=0,column=3,padx=10,pady=10)
searchbtn = Button(Details_frame,text="Shown All",width=10,pady=5).grid(row=0,column=4,padx=10,pady=10)
        
#=======================================Table Font=========================================================================
            
Table_frame =Frame(Details_frame,bd=4,relief=RIDGE,bg="blue")
Table_frame.place(x=10,y=70,width=760,height=500)

#=====================================================Laundry Window========================================================

launwin = Button(Table_frame,text="PLEASE ENTER",command=newLaund,fg="red",bd=10,font=("times new romans",30,"bold"), relief=GROOVE, bg= "white", width=25,pady=15,padx=15)
launwin.pack(side=BOTTOM)


#=====================================================Scroll Bar==========================================================
        
scroll_x = Scrollbar(Table_frame,orient=HORIZONTAL)
scroll_y = Scrollbar(Table_frame,orient=VERTICAL)
laundry_table=ttk.Treeview(Table_frame,column=("roll","name","email","gender","contact","dob","address"),
                                       xscrollcommand=scroll_y,yscrollcommand=scroll_x)
        

        
scroll_x.config()
scroll_y.config()



    
   
    
    
    
    
    
    



     
        
        
        
        
                      
        
        

      
       
              
      

        
        
        
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\HP\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-16-494268b6d784>", line 57, in checkChanges
#     Laundry=laundryVar.get()
# NameError: name 'laundryVar' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\HP\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-16-494268b6d784>", line 57, in checkChanges
#     Laundry=laundryVar.get()
# NameError: name 'laundryVar' is not defined

# %%
from tkinter import *
root = Tk()
options=["Coke","Fanta","Pepsi"]
frame1= Frame(root)
frame1.pack()
itemVar = StringVar()
Label(frame1,text="Item").pack(side=LEFT)
itemVar.set(options[1])
OptionMenu(frame1,itemVar,*options).pack()


sizes=["Small","Medium","Large"]
frame2= Frame(root)
frame2.pack()
sizesVar = StringVar()
Label(frame2,text="Size").pack(side=LEFT)
sizesVar.set(sizes[0])
OptionMenu(frame2,sizesVar,*sizes).pack()

frame3= Frame(root)
frame3.pack()
qtyVar = StringVar()
Label(frame3,text="Quantity").pack(side=LEFT)
Spinbox(frame3,from_=1,to=20).pack()

frame4= Frame(root)
frame4.pack()
qtyVar = StringVar()
Label(frame4,text="Unit Price:700").pack(side=LEFT)

frame5= Frame(root)
frame5.pack()
priceVar = StringVar()
Label(frame5,text="Total Price:700").pack(side=LEFT)


root.mainloop()

# %%
import tkinter as tk
root = Tk()
root.geometry("250x170")
T = Text(root,height = 5, width=10)
